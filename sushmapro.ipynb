# %%
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import re
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams
# %matplotlib inline

# %%
souce=requests.get('https://en.wikipedia.org/wiki/List_of_countries_by_freshwater_withdrawal')
souce
# Out:
# <Response [200]>

# %%
source=BeautifulSoup(souce.text)
source
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of countries by freshwater withdrawal - Wikipedia</title>
# ...

# %%
data1=[]
#data2=[]
data3=[]
data4=[]
data5=[]
data6=[]
data7=[]
data8=[]

# %%
for i in source.find_all('tr'):
    col=i.find_all('td')
    if len(col)==8:
        data1.append(col[0].find(text=True))
        #data2.append(col[1].find(text=True))
        data3.append(col[2].find(text=True))
        data4.append(col[3].find(text=True))
        data5.append(col[4].find(text=True))
        data6.append(col[5].find(text=True))
        data7.append(col[6].find(text=True))
        data8.append(col[7].find(text=True))

# %%
source1=source.find(class_='wikitable sortable')
item1=source1.find_all('a')
data9=[]
for i in item1:
    data=i.text
    data9.append(data)
len(data9)
# Out:
# 172

# %%
data9.pop(169)
# Out:
# 'Comoros'

# %%
data9.pop(170)
# Out:
# 'Maldives'

# %%
len(data9)
# Out:
# 170

# %%
df=pd.DataFrame()

# %%
df['Rank']=data1
df['Country']=data9
df['Totalwithdrawal(km³/year)']=data3
df['Usage_of_water']=data4
df['Domesticwithdrawal(%)']=data5
df['Industrialwithdrawal(%)']=data6
df['Agriculturalwithdrawal(%)']=data7
df['Date of  Information']=data8

# %%
df
# Out:
#     Rank                           Country Totalwithdrawal(km³/year)  \
# 0      1                             India                    645.84
# 1      2                             China                    549.76
# 2      3                     United States                       477
# 3      4                           Vietnam                    169.39
# 4      5                             Japan                     88.43
# 5      6                         Indonesia                     82.78
# 6      7                          Thailand                     82.75
# 7      8                        Uzbekistan                      79.4
# 8      9                            Mexico                     78.22
# 9     10                            Russia                     76.68
# 10    11                              Iran                     72.88
# 11    12                          Pakistan                     71.39
# 12    13                             Egypt                      68.3
# ...

# %%
df.drop(columns='Date of  Information',axis=1,inplace=True)

# %%
df.dtypes
# Out:
# Rank                         object
# Country                      object
# Totalwithdrawal(km³/year)    object
# Usage_of_water               object
# Domesticwithdrawal(%)        object
# Industrialwithdrawal(%)      object
# Agriculturalwithdrawal(%)    object
# dtype: object

# %%
df['Totalwithdrawal(km³/year)']=df['Totalwithdrawal(km³/year)'].apply(pd.to_numeric)

# %%
df['Usage_of_water']=pd.to_numeric(df['Usage_of_water'],errors='coerce')

# %%
df['Domesticwithdrawal(%)']=pd.to_numeric(df['Domesticwithdrawal(%)'],errors='coerce')

# %%
df['Industrialwithdrawal(%)']=pd.to_numeric(df['Industrialwithdrawal(%)'],errors='coerce')

# %%
df['Agriculturalwithdrawal(%)']=pd.to_numeric(df['Agriculturalwithdrawal(%)'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 7 columns):
# Rank                         170 non-null object
# Country                      170 non-null object
# Totalwithdrawal(km³/year)    170 non-null float64
# Usage_of_water               146 non-null float64
# Domesticwithdrawal(%)        162 non-null float64
# Industrialwithdrawal(%)      162 non-null float64
# Agriculturalwithdrawal(%)    162 non-null float64
# dtypes: float64(5), object(2)
# memory usage: 9.4+ KB

# %%
round(100*(df.isnull().sum()/len(df.index)),2)
# Out:
# Rank                          0.00
# Country                       0.00
# Totalwithdrawal(km³/year)     0.00
# Usage_of_water               14.12
# Domesticwithdrawal(%)         4.71
# Industrialwithdrawal(%)       4.71
# Agriculturalwithdrawal(%)     4.71
# dtype: float64

# %%
df.isnull().sum()
# Out:
# Rank                          0
# Country                       0
# Totalwithdrawal(km³/year)     0
# Usage_of_water               24
# Domesticwithdrawal(%)         8
# Industrialwithdrawal(%)       8
# Agriculturalwithdrawal(%)     8
# dtype: int64

# %%
df['Usage_of_water'].describe()
# Out:
# count    146.000000
# mean     331.465753
# std      265.372534
# min        6.000000
# 25%       92.000000
# 50%      285.000000
# 75%      533.500000
# max      977.000000
# Name: Usage_of_water, dtype: float64

# %%
import numpy as np

# %%
df=df[~np.isnan(df['Usage_of_water'])]

# %%
df.isnull().sum()
# Out:
# Rank                         0
# Country                      0
# Totalwithdrawal(km³/year)    0
# Usage_of_water               0
# Domesticwithdrawal(%)        6
# Industrialwithdrawal(%)      6
# Agriculturalwithdrawal(%)    6
# dtype: int64

# %%
df.loc[:,['Domesticwithdrawal(%)','Industrialwithdrawal(%)','Agriculturalwithdrawal(%)']].describe()
# Out:
#        Domesticwithdrawal(%)  Industrialwithdrawal(%)  \
# count             140.000000               140.000000
# mean               23.721429                18.142857
# std                19.703218                22.233416
# min                 0.000000                 0.000000
# 25%                 9.000000                 2.750000
# 50%                19.000000                 9.000000
# 75%                32.000000                23.250000
# max                98.000000                85.000000
#
#        Agriculturalwithdrawal(%)
# count                 140.000000
# mean                   57.757143
# std                    30.410116
# min                     0.000000
# 25%                    38.500000
# 50%                    65.000000
# 75%                    82.000000
# max                   100.000000

# %%
df=df[~np.isnan(df['Domesticwithdrawal(%)'])]

# %%
df.shape
# Out:
# (140, 7)

# %%
df.isnull().sum()
# Out:
# Rank                         0
# Country                      0
# Totalwithdrawal(km³/year)    0
# Usage_of_water               0
# Domesticwithdrawal(%)        0
# Industrialwithdrawal(%)      0
# Agriculturalwithdrawal(%)    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140 entries, 0 to 169
# Data columns (total 7 columns):
# Rank                         140 non-null object
# Country                      140 non-null object
# Totalwithdrawal(km³/year)    140 non-null float64
# Usage_of_water               140 non-null float64
# Domesticwithdrawal(%)        140 non-null float64
# Industrialwithdrawal(%)      140 non-null float64
# Agriculturalwithdrawal(%)    140 non-null float64
# dtypes: float64(5), object(2)
# memory usage: 8.8+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140 entries, 0 to 169
# Data columns (total 7 columns):
# Rank                         140 non-null object
# Country                      140 non-null object
# Totalwithdrawal(km³/year)    140 non-null float64
# Usage_of_water               140 non-null float64
# Domesticwithdrawal(%)        140 non-null float64
# Industrialwithdrawal(%)      140 non-null float64
# Agriculturalwithdrawal(%)    140 non-null float64
# dtypes: float64(5), object(2)
# memory usage: 8.8+ KB

# %%
df['Domesticwithdrawal']=(df['Domesticwithdrawal(%)']/100)*df['Usage_of_water']

# %%
df['Industrialwithdrawal']=(df['Industrialwithdrawal(%)']/100)*df['Usage_of_water']

# %%
df['Agriculturalwithdrawal']=(df['Agriculturalwithdrawal(%)']/100)*df['Usage_of_water']

# %%
df.dtypes
# Out:
# Rank                          object
# Country                       object
# Totalwithdrawal(km³/year)    float64
# Usage_of_water               float64
# Domesticwithdrawal(%)        float64
# Industrialwithdrawal(%)      float64
# Agriculturalwithdrawal(%)    float64
# Domesticwithdrawal           float64
# Industrialwithdrawal         float64
# Agriculturalwithdrawal       float64
# dtype: object

# %%
df.drop(columns='Rank',axis=1,inplace=True)

# %%
df
# Out:
#                               Country  Totalwithdrawal(km³/year)  \
# 0                               India                    645.840
# 1                               China                    549.760
# 4                               Japan                     88.430
# 5                           Indonesia                     82.780
# 7                          Uzbekistan                     79.400
# 8                              Mexico                     78.220
# 9                              Russia                     76.680
# 11                           Pakistan                     71.390
# 12                              Egypt                     68.300
# 13                             Brazil                     59.300
# 17                               Iraq                     41.980
# 18                             Turkey                     39.780
# 19                            Germany                     38.010
# ...

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index     Country  Totalwithdrawal(km³/year)  Usage_of_water  \
# 0      0       India                     645.84           585.0
# 1      1       China                     549.76           415.0
# 2      4       Japan                      88.43           690.0
# 3      5   Indonesia                      82.78           372.0
# 4      7  Uzbekistan                      79.40           560.0
#
#    Domesticwithdrawal(%)  Industrialwithdrawal(%)  Agriculturalwithdrawal(%)  \
# 0                    8.0                      5.0                       86.0
# 1                    7.0                     26.0                       68.0
# 2                   20.0                     18.0                       62.0
# 3                    8.0                      1.0                       91.0
# 4                    3.0                      1.0                       96.0
#
#    Domesticwithdrawal  Industrialwithdrawal  Agriculturalwithdrawal
# ...

# %%
df.drop(columns='index',axis=1,inplace=True)

# %%
df.head()
# Out:
#       Country  Totalwithdrawal(km³/year)  Usage_of_water  \
# 0       India                     645.84           585.0
# 1       China                     549.76           415.0
# 2       Japan                      88.43           690.0
# 3   Indonesia                      82.78           372.0
# 4  Uzbekistan                      79.40           560.0
#
#    Domesticwithdrawal(%)  Industrialwithdrawal(%)  Agriculturalwithdrawal(%)  \
# 0                    8.0                      5.0                       86.0
# 1                    7.0                     26.0                       68.0
# 2                   20.0                     18.0                       62.0
# 3                    8.0                      1.0                       91.0
# 4                    3.0                      1.0                       96.0
#
#    Domesticwithdrawal  Industrialwithdrawal  Agriculturalwithdrawal
# 0               46.80                 29.25                  503.10
# ...

# %%
df.drop(columns='Rank',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-1a134efdc056> in <module>
# ----> 1 df.drop(columns='Rank',axis=1,inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
df.head()

# %%
#df.to_csv('Sriketh_Sushma_project.csv')

# %%
df[['Country']][df['Industrialwithdrawal']>df['Agriculturalwithdrawal']].count()

# %%
df['Wasteage(km3/year)']=df['Totalwithdrawal(km³/year)']-df['Usage_of_water']

# %%
df[df['Wasteage(km3/year)']==df['Wasteage(km3/year)'].min()]

# %%
df

# %%
df['Most Used']=df.loc[:,'Domesticwithdrawal':'Agriculturalwithdrawal'].apply(np.argmax,axis=1)

# %%
df.head()

# %%
df.style.bar('Usage_of_water', color='#d65f5f')

# %%
pi=df['Most Used'].value_counts()
exp=(0.1,0.1,0.1)
pi.plot.pie(explode=exp,autopct='%1.1f%%',shadow=True, startangle=90)

# %%
sns.countplot(x='Most Used',data=df)

# %% [markdown]
# # Totalwithdrawal
# **Highest usage of water**

# %%
dftotal=df[df['Totalwithdrawal(km³/year)']>df['Totalwithdrawal(km³/year)'].mean()]
dftotal

# %%
plt.figure(figsize=(10,10))
plt.barh(dftotal["Country"],width=dftotal["Totalwithdrawal(km³/year)"])
plt.ylabel("Country")
plt.xlabel("Totalwithdrawal(km³/year)")

# %% [markdown]
# # Usage_of_water
# **Top usage of water in country**

# %%
dfusage=df[df['Usage_of_water']>df['Usage_of_water'].mean()]
dfusage

# %%
plt.figure(figsize=(10,15))
plt.barh(dfusage["Country"],width=dfusage["Usage_of_water"])
plt.ylabel("Country")
plt.xlabel("Usage_of_water")
plt.show()

# %% [markdown]
# #  Domesticwithdrawal(%)
# **Top usage of water in domestic**

# %%
dfdomestic=df[df['Domesticwithdrawal(%)']>df['Domesticwithdrawal(%)'].mean()]
dfdomestic

# %%
plt.figure(figsize=(10,15))
plt.barh(dfdomestic["Country"],width=dfdomestic["Domesticwithdrawal(%)"])
plt.xlabel("Domesticwithdrawal(%)")
plt.ylabel("Country")
plt.show()

# %% [markdown]
# # Industrailwithdrawal
# **Top usage of water in Industry**

# %%
dfindustrial=df[df['Industrialwithdrawal(%)']>df['Industrialwithdrawal(%)'].mean()]
dfindustrial

# %%
plt.figure(figsize=(10,15))
plt.barh(dfindustrial["Country"],width=dfindustrial["Industrialwithdrawal(%)"])
plt.xlabel("Industrialwithdrawal(%)")
plt.ylabel("Country")

# %% [markdown]
# # Agriculturalwithdrawal
# **Top usage of water in agriculture in every country**

# %%
dfagriculture=df[df['Agriculturalwithdrawal(%)']>df['Agriculturalwithdrawal(%)'].mean()]
dfagriculture

# %%
dfmean=pd.DataFrame()

# %%
plt.figure(figsize=(15,20))
plt.barh(dfagriculture["Country"],width=dfagriculture["Agriculturalwithdrawal(%)"])
plt.xlabel("Agriculturalwithdrawal(%)")
plt.ylabel("Country")

# %% [markdown]
# # Wasteage(km3/year)
# **Top wastage of water in every country**

# %%
dfwastage=df[df['Wasteage(km3/year)']>df['Wasteage(km3/year)'].mean()]
dfwastage

# %%
plt.figure(figsize=(20,25))
plt.barh(dfwastage["Country"],width=dfwastage["Wasteage(km3/year)"])
plt.xlabel('Wastage')

# %%
data=df.groupby("Country").sum()

# %%
df.mean()

# %% [markdown]
# # UNIVARIATE ANALYSIS
# **Univariate analysis is the simplest form of analyzing data. “Uni” means “one”, so in other words your data has only one variable.**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Totalwithdrawal(km³/year)
#
# **Its has rightskewness of a value=6.6067**

# %%
from scipy import stats

# %%
sns.distplot(dftotal['Totalwithdrawal(km³/year)'],kde=False)

# %% [markdown]
# # Usage_of_water

# %%
sns.distplot(dfusage['Usage_of_water'],kde=False,rug=True,color='R')

# %% [markdown]
# # Domesticwithdrawal(%)
# **It has a rightskewness**
# **skewness value is 1.59676**

# %%
sns.distplot(dfdomestic["Domesticwithdrawal"])

# %% [markdown]
# # Withdrawal Amount(%)

# %%
sns.distplot(dfindustrial["Industrialwithdrawal"])
sns.distplot(dfagriculture["Agriculturalwithdrawal"])
sns.distplot(dfdomestic["Domesticwithdrawal"])
plt.legend(['Industrialwithdrawal','Agriculturalwithdrawal','Domesticwithdrawal'])
plt.xlabel('withdrawal amount')
plt.show()

# %% [markdown]
# # Industrialwithdrawal(%)
# **Industry is highly used in 20-35 range**

# %%
sns.distplot(dfindustrial["Industrialwithdrawal"],kde=False,rug=True)

# %% [markdown]
# #  Agriculturalwithdrawal(%)
# **Agriculture highly used in 90-100 range**

# %%
sns.kdeplot(dfagriculture["Agriculturalwithdrawal"],shade=True)
sns.rugplot(dfagriculture['Agriculturalwithdrawal'])

# %%
sns.kdeplot(dfagriculture['Agriculturalwithdrawal'],shade=True)
sns.distplot(dfagriculture["Agriculturalwithdrawal"],rug=True,kde=False)

# %% [markdown]
# # Wasteage(km3/year)
# **Wastage water mostly used in range of -100 to 0**

# %%
#sns.distplot(dfwastage["Wasteage(km3/year)"],rug=True,kde=False)
sns.kdeplot(dfwastage['Wasteage(km3/year)'],cut=0,shade=True)

# %% [markdown]
# # Bivariate analysis

# %% [markdown]
# #  Total V/s Industry

# %%
plt.figure(figsize=(10,7))
sns.catplot(y="Totalwithdrawal(km³/year)",x="Industrialwithdrawal(%)",kind="bar",data=dftotal,aspect=4,legend=True)
plt.xticks(rotation=90)

# %% [markdown]
# #  Total V/s Domestic

# %%
plt.figure(figsize=(10,7))
sns.catplot(y="Totalwithdrawal(km³/year)",x="Domesticwithdrawal(%)",kind="bar",data=dftotal,aspect=4,legend=True)
plt.xticks(rotation=45)

# %% [markdown]
# # Total v/s Agriculture

# %%
plt.figure(figsize=(10,7))
sns.catplot(y="Totalwithdrawal(km³/year)",x="Agriculturalwithdrawal(%)",kind="bar",data=dftotal,aspect=4,legend=True)
plt.xticks(rotation=45)

# %% [markdown]
# #  Total v/s usage_water

# %%
plt.figure(figsize=(20,15))
sns.catplot(y="Totalwithdrawal(km³/year)",x="Usage_of_water",kind="bar",data=dftotal,aspect=4,legend=True)
plt.xticks(rotation=45)

# %% [markdown]
# # Total v/s Wastage

# %%
plt.figure(figsize=(10,15))
sns.catplot(y="Totalwithdrawal(km³/year)",x="Wasteage(km3/year)",kind="bar",data=dftotal,aspect=4,legend=True)
plt.xticks(rotation=45)

# %% [markdown]
# #  Wastage v/s usage_water

# %%
plt.figure(figsize=(10,20))
sns.catplot(x="Wasteage(km3/year)",y="Usage_of_water",kind="bar",data=dfwastage,aspect=4,legend=True)
plt.xticks(rotation=90)

# %%
dfwastage

# %% [markdown]
# # Wastage v/s Industry

# %%
plt.figure(figsize=(10,15))
sns.catplot(x="Wasteage(km3/year)",y="Industrialwithdrawal(%)",kind="point",data=dfwastage,aspect=4,legend=True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
#  # Wastage v/s Domestic

# %%
plt.figure(figsize=(10,15))
sns.catplot(x="Wasteage(km3/year)",y="Domesticwithdrawal(%)",kind="bar",data=dfwastage,aspect=4,legend=True)
plt.xticks(rotation=90)

# %% [markdown]
# # Wastage v/s Agriculture

# %%
plt.figure(figsize=(10,15))
sns.catplot(x="Wasteage(km3/year)",y="Agriculturalwithdrawal(%)",kind="point",data=dfwastage,aspect=4,legend=True)
plt.xticks(rotation=90)

# %%
dfagriculture

# %% [markdown]
# # Wastage v/s Total

# %%
plt.figure(figsize=(10,15))
sns.catplot(y="Wasteage(km3/year)",x="Totalwithdrawal(km³/year)",kind="point",data=dfwastage,aspect=4,legend=True)
plt.xticks(rotation=90)

# %% [markdown]
# #  Correlation

# %%
a=df.corr()
a

# %%
sns.pairplot(dftotal)

# %%
sns.heatmap(a)

# %% [markdown]
# # Zscore value(95%)
# # For Total,Agricuture,Industrial,domestic

# %%
import scipy.stats 
import scipy
import math

# %%
z95 = scipy.stats.norm.ppf(0.95)
z95
# Out:
# 1.6448536269514722

# %%
df['Totalwithdrawal(km³/year)'].mean()
# Out:
# 18.103521428571455

# %%
df['Totalwithdrawal(km³/year)'].std()
# Out:
# 72.74259062978109

# %%
len(df)
# Out:
# 140

# %%
18.10 + (1.64*72)/math.sqrt(140)
# Out:
# 28.079581439834325

# %%
18.10 - (1.64*72)/math.sqrt(140)
# Out:
# 8.120418560165678

# %%
df['Industrialwithdrawal(%)'].mean()
# Out:
# 18.142857142857142

# %%
df['Industrialwithdrawal(%)'].std()
# Out:
# 22.233415589072756

# %%
18.14 + (1.64*22)/math.sqrt(140)
# Out:
# 21.18931655106049

# %%
18.14 - (1.64*22)/math.sqrt(140)
# Out:
# 15.090683448939513

# %%
df["Domesticwithdrawal(%)"].mean()
# Out:
# 23.72142857142857

# %%
df["Domesticwithdrawal(%)"].std()
# Out:
# 19.70321810516996

# %%
23.72 + (1.64*19)/math.sqrt(140)
# Out:
# 26.353500657734056

# %%
23.72 - (1.64*19)/math.sqrt(140)
# Out:
# 21.08649934226594

# %%
df["Agriculturalwithdrawal(%)"].mean()
# Out:
# 57.75714285714286

# %%
df["Agriculturalwithdrawal(%)"].std()
# Out:
# 30.41011556158006

# %%
57.75 + (1.64*30.14)/math.sqrt(140)
# Out:
# 61.927563674952864

# %%
57.75 -  (1.64*30.14)/math.sqrt(140)
# Out:
# 53.572436325047136

# %% [markdown]
# # Zscore value(99%)
# # For Total,Agricuture,Industrial,domestic

# %%
z99 = scipy.stats.norm.ppf(0.99)
z99
# Out:
# 2.3263478740408408

# %%
18.10 + (2.32*72)/math.sqrt(140)
# Out:
# 32.21745667098514

# %%
18.10 - (2.32*72)/math.sqrt(140)
# Out:
# 3.9825433290148613

# %% [markdown]
# # Industrial

# %%
18.14 + (2.32*22)/math.sqrt(140)
# Out:
# 22.45366731613435

# %%
18.14 - (2.32*22)/math.sqrt(140)
# Out:
# 13.826332683865651

# %% [markdown]
# # domestic

# %%
23.72 + (2.32*19)/math.sqrt(140)
# Out:
# 27.4454399548433

# %%
23.72 - (2.32*19)/math.sqrt(140)
# Out:
# 19.994560045156696

# %% [markdown]
# # Agriculture

# %%
57.75 + (2.32*30.14)/math.sqrt(140)
# Out:
# 63.65972422310406

# %%
57.75 - (2.32*30.14)/math.sqrt(140)
# Out:
# 51.84027577689594

# %% [markdown]
# # Zscore value(90%)
# # For Total,Agricuture,Industrial,domestic

# %% [markdown]
# # Totalwithdrawal

# %%
z90 = scipy.stats.norm.ppf(0.90)
z90
# Out:
# 1.2815515655446004

# %%
18.10 + (1.28*72)/math.sqrt(140)
# Out:
# 25.88894161157801

# %%
18.10 - (1.28*72)/math.sqrt(140)
# Out:
# 10.311058388421994

# %% [markdown]
# # Agriculture

# %%
57.75 + (1.28*30.14)/math.sqrt(140)
# Out:
# 61.01053750240224

# %%
57.75 - (1.28*30.14)/math.sqrt(140)
# Out:
# 54.48946249759776

# %% [markdown]
# # Industry

# %%
18.14 + (1.28*22)/math.sqrt(140)
# Out:
# 20.519954381315504

# %%
18.14 - (1.28*22)/math.sqrt(140)
# Out:
# 15.760045618684497

# %% [markdown]
# # Domestic

# %%
23.72 + (1.28*19)/math.sqrt(140)
# Out:
# 25.77541514749975

# %%
23.72 - (1.28*19)/math.sqrt(140)
# Out:
# 21.664584852500248
